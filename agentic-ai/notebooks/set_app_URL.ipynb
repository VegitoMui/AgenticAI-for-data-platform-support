# %%
from databricks.sdk import WorkspaceClient

w = WorkspaceClient()
w.secrets.put_secret(scope="agentic-ai", key="app-base-url",
                     string_value="https://agentic-ai-approvals-dev-7405617514546966.6.azure.databricksapps.com")
print([s.key for s in w.secrets.list_secrets(scope="agentic-ai")])

# %%
from databricks.sdk import WorkspaceClient

w = WorkspaceClient()
GMAIL = "yashovardhan.rawat@airodigitallabs.com"        # the account that created the App Password
APP_PASSWORD = "kodajnvtdwqjgefq"      # 16 characters, no spaces

w.secrets.put_secret(scope="agentic-ai", key="smtp-user", string_value=GMAIL)
w.secrets.put_secret(scope="agentic-ai", key="smtp-sender", string_value=GMAIL)
w.secrets.put_secret(scope="agentic-ai", key="smtp-password", string_value=APP_PASSWORD)
print("saved")
